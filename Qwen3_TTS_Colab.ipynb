# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [Qwen3-TTS GitHub Repository](https://github.com/QwenLM/Qwen3-TTS)
# * 🤗 [Qwen3-TTS on Hugging Face](https://huggingface.co/collections/Qwen/qwen3-tts)
# * 📄 **License**: Provided under the [Apache License 2.0](https://github.com/QwenLM/Qwen3-TTS?tab=Apache-2.0-1-ov-file)
# * 🤗 [Try Qwen3-TTS on HuggingFace Space](https://huggingface.co/spaces/Qwen/Qwen3-TTS)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install Qwen3-TTS
# %cd /content/
# !rm -rf /content/Qwen3-TTS-Colab
# !git clone https://github.com/NeuralFalconYT/Qwen3-TTS-Colab.git
# !git clone https://github.com/QwenLM/Qwen3-TTS.git
# %cd Qwen3-TTS
# !pip install -e .
# !pip install faster-whisper==1.1.1
# !pip install ctranslate2==4.5.0
# !pip install pysrt
# !pip install sentencex
from IPython.display import Audio,display
from IPython.display import clear_output
import time
clear_output()

display(Audio("https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/audio/warning.mp3", autoplay=True))
time.sleep(6)
clear_output()
# time.sleep(5)
# import os
# os.kill(os.getpid(), 9)

# %%
# %cd /content/Qwen3-TTS-Colab
# !python app.py --share --debug
# Out:
# /content/Qwen3-TTS-Colab
# 2026-01-28 11:30:30.533770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769599830.553926    3098 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769599830.560035    3098 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769599830.575567    3098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769599830.575595    3098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769599830.575599    3098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769599830.575602    3098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-28 11:30:30.580431: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ********
# Warning: flash-attn is not installed. Will only run the manual PyTorch version. Please install flash-attn for faster inference.
# ********
#
# /bin/sh: 1: sox: not found
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
#
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# /content/Qwen3-TTS-Colab/app.py:354: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="Qwen3-TTS Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://af5efd1b282b31f0aa.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Processing 1 chunks...
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
#
# preprocessor_config.json: 100% 127/127 [00:00<00:00, 1.17MB/s]
# config.json: 4.42kB [00:00, 918kB/s]
#
# merges.txt: 0.00B [00:00, ?B/s]
#
# .gitattributes: 1.52kB [00:00, 8.54MB/s]
#
#
# generation_config.json: 100% 245/245 [00:00<00:00, 2.41MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:03,  3.01it/s]
#
# config.json: 2.34kB [00:00, 12.6MB/s]
#
#
# README.md: 57.8kB [00:00, 89.9MB/s]
# merges.txt: 1.67MB [00:00, 32.3MB/s]
#
# configuration.json: 100% 76.0/76.0 [00:00<00:00, 701kB/s]
#
# tokenizer_config.json: 7.34kB [00:00, 36.5MB/s]
#
# preprocessor_config.json: 100% 234/234 [00:00<00:00, 2.51MB/s]
#
# model.safetensors:   0% 0.00/3.83G [00:00<?, ?B/s]
#
# vocab.json: 2.78MB [00:00, 97.7MB/s]
#
#
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
#
# speech_tokenizer/model.safetensors:   1% 7.34M/682M [00:01<02:23, 4.69MB/s]
# model.safetensors:   0% 650k/3.83G [00:01<2:55:51, 363kB/s]
#
# speech_tokenizer/model.safetensors:   5% 32.9M/682M [00:01<00:32, 20.3MB/s]
# model.safetensors:   0% 2.06M/3.83G [00:02<1:15:23, 847kB/s]
#
# speech_tokenizer/model.safetensors:   7% 45.3M/682M [00:02<00:34, 18.6MB/s]
# model.safetensors:   2% 69.1M/3.83G [00:06<04:53, 12.8MB/s]
# model.safetensors:   4% 136M/3.83G [00:06<02:08, 28.7MB/s]
# model.safetensors:   5% 203M/3.83G [00:07<01:17, 46.9MB/s]
# model.safetensors:   7% 270M/3.83G [00:07<00:56, 62.6MB/s]
# model.safetensors:   9% 338M/3.83G [00:08<00:54, 64.6MB/s]
# model.safetensors:  11% 405M/3.83G [00:11<01:19, 43.4MB/s]
# model.safetensors:  14% 540M/3.83G [00:11<00:46, 70.2MB/s]
# model.safetensors:  16% 607M/3.83G [00:12<00:35, 91.0MB/s]
# model.safetensors:  18% 674M/3.83G [00:15<01:07, 46.8MB/s]
# model.safetensors:  21% 808M/3.83G [00:15<00:41, 72.4MB/s]
# model.safetensors:  23% 875M/3.83G [00:16<00:35, 82.6MB/s]
#
# speech_tokenizer/model.safetensors:  16% 112M/682M [00:16<01:32, 6.14MB/s]
#
# speech_tokenizer/model.safetensors:  26% 179M/682M [00:16<00:40, 12.4MB/s]
#
# speech_tokenizer/model.safetensors:  36% 247M/682M [00:21<00:33, 13.0MB/s]
# model.safetensors:  25% 942M/3.83G [00:21<01:23, 34.8MB/s]
#
# speech_tokenizer/model.safetensors:  51% 347M/682M [00:21<00:14, 23.4MB/s]
# model.safetensors:  26% 1.01G/3.83G [00:27<02:07, 22.1MB/s]
#
# speech_tokenizer/model.safetensors:  61% 414M/682M [00:27<00:14, 17.9MB/s]
# model.safetensors:  28% 1.08G/3.83G [00:28<01:39, 27.8MB/s]
#
# speech_tokenizer/model.safetensors:  61% 414M/682M [00:39<00:14, 17.9MB/s]
# model.safetensors:  28% 1.08G/3.83G [00:39<01:39, 27.8MB/s]
# model.safetensors:  30% 1.14G/3.83G [00:50<05:23, 8.33MB/s]
# model.safetensors:  30% 1.17G/3.83G [00:55<05:42, 7.79MB/s]
# model.safetensors:  32% 1.24G/3.83G [00:56<03:49, 11.3MB/s]
#
# speech_tokenizer/model.safetensors:  71% 481M/682M [00:56<00:34, 5.88MB/s]
# model.safetensors:  34% 1.30G/3.83G [00:56<02:35, 16.2MB/s]
# model.safetensors:  36% 1.39G/3.83G [00:57<01:48, 22.5MB/s]
# model.safetensors:  38% 1.45G/3.83G [01:02<02:04, 19.0MB/s]
# model.safetensors:  40% 1.52G/3.83G [01:02<01:26, 26.7MB/s]
# model.safetensors:  41% 1.59G/3.83G [01:02<01:01, 36.3MB/s]
# model.safetensors:  43% 1.66G/3.83G [01:03<00:44, 48.6MB/s]
# model.safetensors:  45% 1.72G/3.83G [01:03<00:32, 64.3MB/s]
# model.safetensors:  47% 1.79G/3.83G [01:03<00:24, 82.8MB/s]
# model.safetensors:  48% 1.86G/3.83G [01:03<00:19, 103MB/s]
# model.safetensors:  50% 1.92G/3.83G [01:04<00:15, 126MB/s]
# model.safetensors:  52% 1.99G/3.83G [01:04<00:13, 136MB/s]
#
# speech_tokenizer/model.safetensors:  80% 548M/682M [01:04<00:21, 6.38MB/s]
# model.safetensors:  54% 2.06G/3.83G [01:05<00:13, 136MB/s]
# model.safetensors:  56% 2.14G/3.83G [01:05<00:10, 158MB/s]
# model.safetensors:  58% 2.21G/3.83G [01:05<00:08, 189MB/s]
# model.safetensors:  59% 2.28G/3.83G [01:05<00:07, 216MB/s]
# model.safetensors:  61% 2.34G/3.83G [01:06<00:07, 190MB/s]
#
# speech_tokenizer/model.safetensors:  90% 615M/682M [01:06<00:07, 8.61MB/s]
# model.safetensors:  63% 2.41G/3.83G [01:06<00:07, 184MB/s]
# model.safetensors:  65% 2.48G/3.83G [01:06<00:06, 222MB/s]
# model.safetensors:  66% 2.54G/3.83G [01:06<00:05, 243MB/s]
# model.safetensors:  68% 2.61G/3.83G [01:07<00:04, 252MB/s]
# model.safetensors:  70% 2.68G/3.83G [01:07<00:04, 241MB/s]
# model.safetensors:  72% 2.74G/3.83G [01:07<00:05, 210MB/s]
# model.safetensors:  75% 2.88G/3.83G [01:08<00:04, 213MB/s]
# model.safetensors:  77% 2.95G/3.83G [01:08<00:04, 199MB/s]
# model.safetensors:  79% 3.01G/3.83G [01:14<00:21, 38.4MB/s]
# model.safetensors:  80% 3.08G/3.83G [01:14<00:14, 51.5MB/s]
# model.safetensors:  83% 3.16G/3.83G [01:15<00:09, 69.4MB/s]
# model.safetensors:  84% 3.23G/3.83G [01:15<00:06, 86.0MB/s]
#
# speech_tokenizer/model.safetensors: 100% 682M/682M [01:15<00:00, 9.01MB/s]
#
# model.safetensors:  86% 3.30G/3.83G [01:16<00:05, 90.1MB/s]
# model.safetensors:  88% 3.37G/3.83G [01:22<00:17, 27.2MB/s]
# model.safetensors:  91% 3.50G/3.83G [01:23<00:07, 47.4MB/s]
# model.safetensors:  93% 3.57G/3.83G [01:30<00:11, 24.2MB/s]
# model.safetensors:  93% 3.57G/3.83G [01:49<00:11, 24.2MB/s]
# model.safetensors:  95% 3.63G/3.83G [02:08<00:35, 5.64MB/s]
# model.safetensors:  97% 3.70G/3.83G [02:09<00:17, 7.49MB/s]
# model.safetensors:  98% 3.77G/3.83G [02:09<00:06, 10.3MB/s]
# model.safetensors: 100% 3.83G/3.83G [02:09<00:00, 29.5MB/s]
# Fetching 13 files: 100% 13/13 [02:10<00:00, 10.03s/it]
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# Stitching 1 audio files...
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://af5efd1b282b31f0aa.gradio.live
# ^C
